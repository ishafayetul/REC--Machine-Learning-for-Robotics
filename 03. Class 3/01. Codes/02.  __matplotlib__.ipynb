# %% [markdown]
# # Matplotlib Tutorial

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # 1. Line Graph

# %% [markdown]
# - ## Data

# %%
X = [1, 2, 3, 4, 5]
Y = [0.90, 0.70, 0.55, 0.45, 0.40]

# %% [markdown]
# - ## Ploting

# %%
plt.plot(X, Y) # Plot the data

# %% [markdown]
# - ## Decoration

# %%
plt.figure(figsize=(15, 4)) # Set the figure size
plt.plot(X, Y) # Plot the data

# %%
plt.figure(figsize=(15, 4)) # Set the figure size
plt.title("X vs Y Plot") # Add a title
plt.plot(X, Y) # Plot the data

# %%
plt.figure(figsize=(15, 4)) # Set the figure size
plt.title("X vs Y Plot") # Add a title
plt.xlabel("X values") # Label for X-axis
plt.ylabel("Y values") # Label for Y-axis
plt.plot(X, Y) # Plot the data

# %%
plt.figure(figsize=(15, 4)) # Set the figure size
plt.title("X vs Y Plot") # Add a title
plt.xlabel("X values") # Label for X-axis
plt.ylabel("Y values") # Label for Y-axis
plt.plot(X, Y) # Plot the data
plt.grid(True, alpha=0.3)

# %%
plt.figure(figsize=(15, 4)) # Set the figure size
plt.title("X vs Y Plot") # Add a title
plt.xlabel("X values") # Label for X-axis
plt.ylabel("Y values") # Label for Y-axis
plt.plot(X, Y) # Plot the data
plt.grid(True, alpha=0.3)
plt.show()

'''
plt.plot(...)
    Creates the plot objects (adds a line/curve to the current figure/axes).
    It does not guarantee the plot will appear on screen by itself.

plt.show()
    Displays/renders the current figure window (or outputs the figure in notebooks).
    Usually called after you finish adding everything (plot, labels, legend, grid).
'''
# Out:
# '\nplt.plot(...)\n    Creates the plot objects (adds a line/curve to the current figure/axes).\n    It does not guarantee the plot will appear on screen by itself.\n\nplt.show()\n    Displays/renders the current figure window (or outputs the figure in notebooks).\n    Usually called after you finish adding everything (plot, labels, legend, grid).\n'

# %% [markdown]
# - ## Multiple Plots in Single Diagram

# %%
x = [1, 2, 3, 4, 5]

y1 = [2, 4, 6, 8, 10]
y2 = [1, 2, 4, 8, 16]
y3 = [10, 9, 7, 6, 5]

# %%
plt.plot(x, y1, label="Line 1") # Plot line 1
plt.plot(x, y2, label="Line 2") # Plot line 2
plt.plot(x, y3, label="Line 3") # Plot line 3

plt.title("Multiple Line Graph Without Legend") # Add title
plt.xlabel("x") # Add labels
plt.ylabel("y") # Add labels
plt.grid(True, alpha=0.3)   # Add grid
plt.show()  # Display the plot

# %%
plt.plot(x, y1, label="Line 1") # Plot line 1
plt.plot(x, y2, label="Line 2") # Plot line 2
plt.plot(x, y3, label="Line 3") # Plot line 3

plt.title("Multiple Line Graph With Legend") # Add title
plt.xlabel("x") # Add labels
plt.ylabel("y") # Add labels
plt.legend()    # Show legend
plt.grid(True, alpha=0.3)   # Add grid
plt.show()  # Display the plot

# %% [markdown]
# # 2. Histogram

# %%
data = [1.2, 2.3, 2.9, 3.1, 3.8, 4.0, 4.2, 5.5, 6.1, 6.8]

plt.figure(figsize=(7, 4))  # Set the figure size
plt.hist(data, bins=6, edgecolor="black")   # Create histogram
plt.title("Histogram")  # Add title
plt.xlabel("Value") # Label for X-axis
plt.ylabel("Count") # Label for Y-axis
plt.grid(True, alpha=0.3)   # Add grid
plt.show()  # Display the plot

# %% [markdown]
# # 3. Scatter plot

# %%
x = [1, 2, 3, 4, 5, 6]
y = [2.1, 2.9, 3.7, 4.2, 5.1, 5.9]

plt.figure(figsize=(7, 4))
plt.scatter(x, y)
plt.title("Scatter Plot", )
plt.xlabel("Feature (x)")
plt.ylabel("Target (y)")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # 4. Box plot

# %%
group_a = [10, 12, 13, 12, 11, 14, 30]   # 30 is an outlier
group_b = [8, 9, 10, 11, 9, 10, 12]

plt.figure(figsize=(7, 4))
plt.boxplot([group_a, group_b], tick_labels=["Group A", "Group B"])
plt.title("Box Plot")
plt.ylabel("Value")
plt.grid(True, axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# # 5. Heatmap

# %%
matrix = [
    [1.0, 0.8, 0.2],
    [0.8, 1.0, 0.5],
    [0.2, 0.5, 1.0]
]

plt.figure(figsize=(6, 5))
plt.imshow(matrix)
plt.title("Heatmap")
plt.xticks([0, 1, 2], ["F1", "F2", "F3"])
plt.yticks([0, 1, 2], ["F1", "F2", "F3"])
plt.colorbar(label="Value")

# %% [markdown]
# # 6. Bar chart

# %%
classes = ["Cat", "Dog", "Bird"]
counts = [50, 35, 15]

plt.figure(figsize=(7, 4))
plt.bar(classes, counts, edgecolor="black")
plt.title("Bar Chart (Class Counts)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.grid(True, axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# # 7. Image

# %%
import matplotlib.image as mpimg

img = mpimg.imread("image.png") # path to your image file
plt.figure(figsize=(8, 5)) # Set the figure size
plt.imshow(img) # Display the image
plt.axis("off")          # hide axes
plt.title("Image")
plt.show()

# %% [markdown]
# ## 7.1 Multiple Images (Side by Side)

# %%
img1 = mpimg.imread("image.png")
img2 = mpimg.imread("image.png")

fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].imshow(img1); ax[0].axis("off"); ax[0].set_title("Image 1")
ax[1].imshow(img2); ax[1].axis("off"); ax[1].set_title("Image 2")
plt.show()

# %% [markdown]
# ## 7.2 Multiple Images (Grid)

# %%
# load images
img1 = mpimg.imread("image.png")
img2 = mpimg.imread("image.png")
img3 = mpimg.imread("image.png")
img4 = mpimg.imread("image.png")

# create 2x2 grid
fig, ax = plt.subplots(2, 2, figsize=(15, 10))

ax[0, 0].imshow(img1); ax[0, 0].set_title("Image 1 [0,0]"); ax[0, 0].axis("off")
ax[0, 1].imshow(img2); ax[0, 1].set_title("Image 2 [0,1]"); ax[0, 1].axis("off")
ax[1, 0].imshow(img3); ax[1, 0].set_title("Image 3 [1,0]"); ax[1, 0].axis("off")
ax[1, 1].imshow(img4); ax[1, 1].set_title("Image 4 [1,1]"); ax[1, 1].axis("off")

plt.tight_layout()
plt.show()
